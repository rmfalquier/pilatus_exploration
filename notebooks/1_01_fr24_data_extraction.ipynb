# %% [markdown]
# ## Load API keys

# %%
import os
import yaml
import pandas as pd
import requests
import json
import time
import random
from datetime import datetime, timedelta

from IPython.display import clear_output

# %%
def load_api_keys(yaml_path=None):
    """
    Load API keys from a YAML file.

    :param yaml_path: Path to the YAML file (optional).
    :return: A dictionary with API keys.
    """
    # Default path to the keys.yml file
    if not yaml_path:
        yaml_path = os.path.expanduser("../project_keys.yml")
    
    try:
        with open(yaml_path, 'r') as file:
            data = yaml.safe_load(file)
            return data.get('api_keys', {})
    except FileNotFoundError:
        raise FileNotFoundError(f"API keys file not found at: {yaml_path}")
    except yaml.YAMLError as e:
        raise Exception(f"Error parsing YAML file: {e}")

# %%
# Load API keys
api_keys = load_api_keys()

# Access individual keys
flightradar_key = api_keys.get('Flightradar24_flight-lab-01')

# %% [markdown]
# ## Flightradar API requests

# %% [markdown]
# ### Swedish Flight Ambulance Service PC-24

# %%
# Swedish flight ambulance registrations
sva_regs = ['SE-RVA','SE-RVB','SE-RVC','SE-RVD','SE-RVE','SE-RVF']

# Put all elements of the sva_regs list into a string separated by commas
sva_ac_regs_string = ','.join(sva_regs)
sva_ac_regs_string
# Out:
# 'SE-RVA,SE-RVB,SE-RVC,SE-RVD,SE-RVE,SE-RVF'

# %% [markdown]
# ## Flight positions
#
# - **I have 309'493 credits remaining**
# - **2'000 missions cost 80'000 for tracks and 16'000 for positions i.e. about 100k credits**
# - **Budget allows for approx. 6'000 missions**

# %%
def sva_flight_positions(flightradar_key,sva_ac_regs_string,save_path_root,start_date,end_date,splits_per_hour) :
  # API Parameters
  API_TOKEN = flightradar_key
  url = "https://fr24api.flightradar24.com/api/historic/flight-positions/full"
  
  params = {
    'registrations': sva_ac_regs_string #	Aircraft registration numbers (comma-separated values)
  }

  headers = {
          'Accept': 'application/json',
          'Accept-Version': 'v1',
          'Authorization': f'Bearer {API_TOKEN}',
          }

  # Define Save Path
  progress_save_path = "../data/raw" + "/progress_and_errors" + save_path_root.split("../data/raw")[1]
  last_progress_save = "No progress save yet"

  # Define date ranges
  dates = pd.date_range(start=start_date, end=end_date, freq='h')
  query_no = 0

  # Initialize the DataFrame to store data
  df_flight_position = pd.DataFrame()
  break_flag = False

  # Loop through the dates and timestamps to search for REGA data in API
  for j, date in enumerate(dates): 
    timestamps = []

    # Generate the timestamps for the hour based on the splits per hour
    for split in range(splits_per_hour):
      minute = int((60/splits_per_hour) * split)
      timestamp = int(datetime(date.year, date.month, date.day, date.hour, minute).timestamp())  # Generate the timestamp for the hour
      timestamps.append(timestamp)
    
    # Loop through the timestamps
    for k, timestamp in enumerate(timestamps): 
        query_no += 1
        time.sleep(0.67) 
        params['timestamp'] = timestamp 
        
        # Credit check for track extraction
        credits_remaining = (218788 - (query_no*8))
        missions_extractable = (credits_remaining/40)
        if (j==0 and k==0) or (len(df_flight_position)==0) :
          missions_in_set = 5457
        else :
          missions_in_set = len(list(df_flight_position['fr24_id'].unique())) + 5457
        
        # Debugging line
        clear_output(wait=True)    
        print(f"Date range from {start_date} to {end_date}")
        print(f"Query {query_no} of expected {len(timestamps)*len(dates)}")
        print(last_progress_save)
        print(f"Date {j+1} of {len(dates)} and Timestamp {k+1} of {len(timestamps)}")
        print(f"Will attempt requesting on date {date} at timestamp {timestamp}") 

        try:
            if missions_in_set < missions_extractable:
              print(f"Missions in set {missions_in_set} < Missions extractable {missions_extractable}, will proceed with request!")
              print(f"Credits Remaining: {credits_remaining}")
              response = requests.get(url, headers=headers, params=params)
              response.raise_for_status()
              data = response.json()

              if isinstance(data, dict) and "data" in data and isinstance(data["data"], list) and data["data"]:
                print(json.dumps(data, indent=4))  # Debugging line
                # If data is found, append it to the DataFrame
                df_flight_position = pd.concat([df_flight_position, pd.DataFrame(data["data"])], ignore_index=True)

              else:
                print(f"No data found for date {date} at timestamp {timestamp}")

            else:
              break_flag = True
              print(f"WARNING!!! Missions in set {missions_in_set} > Missions extractable {missions_extractable}, will cancel request!")
              break
              
        except requests.exceptions.HTTPError as http_err:
              print(f"HTTP error occurred: {http_err}")
              time_of_error = int(time.time())
              save_path = progress_save_path + str(time_of_error) + "_http_error.csv"
              df_flight_position.to_csv(save_path, index=False)
  
        except Exception as err:
              print(f"An error occurred: {err}")
              time_of_error = int(time.time())
              save_path = progress_save_path + str(time_of_error) + "_error.csv"
              df_flight_position.to_csv(save_path, index=False)
    
    # In loop progress saving for every 7th day in date range
    if (query_no) % (7*24*splits_per_hour) == 0 :
      time_of_progress_save = int(time.time())
      save_path = progress_save_path + str(date) + "_" + str(time_of_progress_save) + ".csv"
      df_flight_position.to_csv(save_path, index=False)
      last_progress_save = f"The last progress save was on {str(date)} at {str(time_of_progress_save)}"
    
    if break_flag :
      break

  # Final Saving
  time_of_run = int(time.time())
  save_path = save_path_root + str(splits_per_hour) + "_splitsperhour_final_" + str(time_of_run) + ".csv"
  df_flight_position.to_csv(save_path, index=False)

  print("GREAT SUCCESS!!!!!!!!!!")
  return df_flight_position

# %%
save_path_root = "../data/raw/df_flight_position_20241103_20241231_" # No need to end with .csv, leave as "_" for timestamp
start_date = datetime(2024, 11, 3, 0, 0, 0)
end_date = datetime(2024, 12, 31, 23, 59, 59)
splits_per_hour = 2

# sva_flight_positions = sva_flight_positions(flightradar_key,sva_ac_regs_string,save_path_root,start_date,end_date,splits_per_hour)
# Out:
# Date range from 2024-11-03 00:00:00 to 2024-12-31 23:59:59
# Query 39 of expected 2832
# No progress save yet
# Date 20 of 1416 and Timestamp 1 of 2
# Will attempt requesting on date 2024-11-03 19:00:00 at timestamp 1730656800
# WARNING!!! Missions in set 5462 > Missions extractable 5461.9, will cancel request!
# GREAT SUCCESS!!!!!!!!!!

# %%
# Load the data
sva_flight_positions = pd.read_csv("../data/raw/sva_flight_positions_full.csv")

# Drop duplicates based on unique ID 'fr24_id'
sva_flight_positions.drop_duplicates(subset=['fr24_id'], inplace=True)

 # Sort by unique ID 'fr24_id'
sva_flight_positions.sort_values(by=['fr24_id'], inplace=True)

# Verify the list length
print(len(sva_flight_positions))

# Save the cleaned data
sva_flight_positions.to_csv("../data/raw/sva_flight_positions_reduced.csv", index=False)
# Out:
# 5462

# %% [markdown]
# #### Flight tracks
#
# **NOTE: does SVA use a specific SQWAK for emergencies?**

# %%
def sva_flight_track(flightradar_key,save_path_root,sva_flight_positions_path) :
  # API Parameters
  API_TOKEN = flightradar_key
  url = "https://fr24api.flightradar24.com/api/flight-tracks"

  headers = {
      'Accept': 'application/json',
      'Accept-Version': 'v1',
      'Authorization': f'Bearer {API_TOKEN}',
      }
  
  # Define Save Path
  progress_save_path = "../data/raw" + "/progress_and_errors" + save_path_root.split("../data/raw")[1]
  last_progress_save = "No progress save yet"

  # Flight ID extraction
  sva_flight_positions = pd.read_csv(sva_flight_positions_path)
  flight_ids = list(sva_flight_positions['fr24_id'].unique())

  # Initialize the DataFrame to store data
  df_flight_track = pd.DataFrame(columns=["flight_id", "mission"]).set_index("flight_id")

  # FR_24 ID Based Request Loop
  for i, flight_id in enumerate(flight_ids) :
    # API Parameterization with FR_24 ID and Wait Time
    time.sleep(0.67) 
    params = {
      'flight_id': flight_id #	Aircraft registration numbers (comma-separated values)
    }

    # Debugging line
    clear_output(wait=True)    
    print(f"Request number {i+1} of {len(flight_ids)}, requesting for flight_id {flight_id}") 
    print(last_progress_save)

    try:  
      response = requests.get(url, headers=headers, params=params)
      response.raise_for_status()
      data = response.json()
      print(json.dumps(data, indent=4))
      
      if isinstance(data[0], dict) and "tracks" in data[0] and isinstance(data[0]["tracks"], list) and data[0]["tracks"] :        
        # If data is found, append it to the DataFrame
        tracks_data = data[0]["tracks"]  
        df_flight_track.loc[flight_id] = [tracks_data]

      else:
        print(f"No data found for flight_id {flight_id}")

    except requests.exceptions.HTTPError as http_err:
      print(f"HTTP error occurred: {http_err}")
      time_of_error = int(time.time())
      save_path = progress_save_path + str(time_of_error) + "_http_error.csv"
      df_flight_track.to_csv(save_path, index=True)

    except Exception as err:
      print(f"An error occurred: {err}")
      time_of_error = int(time.time())
      save_path = progress_save_path + str(time_of_error) + "_error.csv"
      df_flight_track.to_csv(save_path, index=True)

    # In loop progress saving for every 400th mission date range
    if (i+1) % 200 == 0 :
      time_of_progress_save = int(time.time())
      save_path = progress_save_path + "mission_" + str(i+1) + "_of_" + str(len(flight_ids)) + "_" +str(time_of_progress_save) + ".csv"
      df_flight_track.to_csv(save_path, index=True)
      last_progress_save = f"The last progress save was on the {i+1}th mission at {str(time_of_progress_save)}"
      

  # Final Saving
  time_of_run = int(time.time())
  save_path = save_path_root + "final_" + str(time_of_run) + ".csv"
  df_flight_track.to_csv(save_path, index=True)

  print("GREAT SUCCESS!!!!!!!!!!")
  return df_flight_track

# %%
sva_flight_positions_path = "../data/raw/sva_flight_positions_reduced.csv"
save_path_root = "../data/raw/df_flight_tracks_20240101_20241103_" # No need to end with .csv, leave as "_" for timestamp
rega_flight_tracks = sva_flight_track(flightradar_key,save_path_root,sva_flight_positions_path)
# Out:
# Request number 5462 of 5462, requesting for flight_id 37d4b992
# The last progress save was on the 5400th mission at 1738858465
# [
#     {
#         "fr24_id": "37d4b992",
#         "tracks": [
#             {
#                 "timestamp": "2024-11-03T14:30:48Z",
#                 "lat": 63.19818,
#                 "lon": 14.49448,
#                 "alt": 0,
#                 "gspeed": 0,
#                 "vspeed": 0,
#                 "track": 295,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:09Z",
#                 "lat": 63.19812,
#                 "lon": 14.49416,
#                 "alt": 0,
#                 "gspeed": 3,
#                 "vspeed": 0,
#                 "track": 233,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:23Z",
#                 "lat": 63.1978,
#                 "lon": 14.49398,
#                 "alt": 0,
#                 "gspeed": 8,
#                 "vspeed": 0,
#                 "track": 180,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:28Z",
#                 "lat": 63.19757,
#                 "lon": 14.49422,
#                 "alt": 0,
#                 "gspeed": 12,
#                 "vspeed": 0,
#                 "track": 143,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:31Z",
#                 "lat": 63.19747,
#                 "lon": 14.49445,
#                 "alt": 0,
#                 "gspeed": 13,
#                 "vspeed": 0,
#                 "track": 129,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:36Z",
#                 "lat": 63.19728,
#                 "lon": 14.49521,
#                 "alt": 0,
#                 "gspeed": 16,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:40Z",
#                 "lat": 63.19717,
#                 "lon": 14.4958,
#                 "alt": 0,
#                 "gspeed": 18,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:45Z",
#                 "lat": 63.19698,
#                 "lon": 14.49672,
#                 "alt": 0,
#                 "gspeed": 20,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:46Z",
#                 "lat": 63.19691,
#                 "lon": 14.49704,
#                 "alt": 0,
#                 "gspeed": 21,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:48Z",
#                 "lat": 63.19686,
#                 "lon": 14.49725,
#                 "alt": 0,
#                 "gspeed": 21,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:50Z",
#                 "lat": 63.19676,
#                 "lon": 14.49776,
#                 "alt": 0,
#                 "gspeed": 21,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:52Z",
#                 "lat": 63.19669,
#                 "lon": 14.49811,
#                 "alt": 0,
#                 "gspeed": 20,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:54Z",
#                 "lat": 63.19659,
#                 "lon": 14.49852,
#                 "alt": 0,
#                 "gspeed": 20,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:57Z",
#                 "lat": 63.19647,
#                 "lon": 14.49913,
#                 "alt": 0,
#                 "gspeed": 21,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:41:59Z",
#                 "lat": 63.1964,
#                 "lon": 14.49944,
#                 "alt": 0,
#                 "gspeed": 21,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:42:00Z",
#                 "lat": 63.19635,
#                 "lon": 14.49974,
#                 "alt": 0,
#                 "gspeed": 21,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:42:02Z",
#                 "lat": 63.19628,
#                 "lon": 14.50007,
#                 "alt": 0,
#                 "gspeed": 21,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:42:10Z",
#                 "lat": 63.19595,
#                 "lon": 14.50165,
#                 "alt": 0,
#                 "gspeed": 21,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:42:19Z",
#                 "lat": 63.19553,
#                 "lon": 14.50363,
#                 "alt": 0,
#                 "gspeed": 23,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:42:26Z",
#                 "lat": 63.19519,
#                 "lon": 14.50531,
#                 "alt": 0,
#                 "gspeed": 24,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:42:34Z",
#                 "lat": 63.19484,
#                 "lon": 14.50699,
#                 "alt": 0,
#                 "gspeed": 24,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:42:42Z",
#                 "lat": 63.19444,
#                 "lon": 14.50892,
#                 "alt": 0,
#                 "gspeed": 24,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:42:49Z",
#                 "lat": 63.19409,
#                 "lon": 14.51057,
#                 "alt": 0,
#                 "gspeed": 24,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:42:55Z",
#                 "lat": 63.19382,
#                 "lon": 14.51191,
#                 "alt": 0,
#                 "gspeed": 24,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:43:04Z",
#                 "lat": 63.19339,
#                 "lon": 14.51393,
#                 "alt": 0,
#                 "gspeed": 24,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:43:12Z",
#                 "lat": 63.19302,
#                 "lon": 14.51574,
#                 "alt": 0,
#                 "gspeed": 24,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:43:19Z",
#                 "lat": 63.19271,
#                 "lon": 14.5173,
#                 "alt": 0,
#                 "gspeed": 22,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:43:27Z",
#                 "lat": 63.19239,
#                 "lon": 14.51884,
#                 "alt": 0,
#                 "gspeed": 20,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:43:34Z",
#                 "lat": 63.19212,
#                 "lon": 14.52015,
#                 "alt": 0,
#                 "gspeed": 18,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:43:41Z",
#                 "lat": 63.19186,
#                 "lon": 14.52136,
#                 "alt": 0,
#                 "gspeed": 16,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:43:48Z",
#                 "lat": 63.19164,
#                 "lon": 14.5224,
#                 "alt": 0,
#                 "gspeed": 15,
#                 "vspeed": 0,
#                 "track": 115,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:43:55Z",
#                 "lat": 63.19146,
#                 "lon": 14.52319,
#                 "alt": 0,
#                 "gspeed": 13,
#                 "vspeed": 0,
#                 "track": 120,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:43:57Z",
#                 "lat": 63.19139,
#                 "lon": 14.52342,
#                 "alt": 0,
#                 "gspeed": 13,
#                 "vspeed": 0,
#                 "track": 126,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:43:59Z",
#                 "lat": 63.19131,
#                 "lon": 14.52365,
#                 "alt": 0,
#                 "gspeed": 12,
#                 "vspeed": 0,
#                 "track": 129,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:44:03Z",
#                 "lat": 63.19117,
#                 "lon": 14.52398,
#                 "alt": 0,
#                 "gspeed": 11,
#                 "vspeed": 0,
#                 "track": 135,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:44:06Z",
#                 "lat": 63.19104,
#                 "lon": 14.52422,
#                 "alt": 0,
#                 "gspeed": 10,
#                 "vspeed": 0,
#                 "track": 140,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:44:10Z",
#                 "lat": 63.1909,
#                 "lon": 14.52446,
#                 "alt": 0,
#                 "gspeed": 9,
#                 "vspeed": 0,
#                 "track": 146,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:44:15Z",
#                 "lat": 63.1907,
#                 "lon": 14.52469,
#                 "alt": 0,
#                 "gspeed": 9,
#                 "vspeed": 0,
#                 "track": 151,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:44:22Z",
#                 "lat": 63.19045,
#                 "lon": 14.52487,
#                 "alt": 0,
#                 "gspeed": 7,
#                 "vspeed": 0,
#                 "track": 165,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:44:30Z",
#                 "lat": 63.19022,
#                 "lon": 14.52492,
#                 "alt": 0,
#                 "gspeed": 6,
#                 "vspeed": 0,
#                 "track": 182,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:44:40Z",
#                 "lat": 63.19001,
#                 "lon": 14.52482,
#                 "alt": 0,
#                 "gspeed": 5,
#                 "vspeed": 0,
#                 "track": 194,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:44:51Z",
#                 "lat": 63.18979,
#                 "lon": 14.52459,
#                 "alt": 0,
#                 "gspeed": 6,
#                 "vspeed": 0,
#                 "track": 210,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:44:57Z",
#                 "lat": 63.18963,
#                 "lon": 14.52433,
#                 "alt": 0,
#                 "gspeed": 7,
#                 "vspeed": 0,
#                 "track": 222,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:45:00Z",
#                 "lat": 63.18957,
#                 "lon": 14.52413,
#                 "alt": 0,
#                 "gspeed": 6,
#                 "vspeed": 0,
#                 "track": 244,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:45:04Z",
#                 "lat": 63.18958,
#                 "lon": 14.5239,
#                 "alt": 0,
#                 "gspeed": 5,
#                 "vspeed": 0,
#                 "track": 278,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:45:14Z",
#                 "lat": 63.18963,
#                 "lon": 14.5237,
#                 "alt": 0,
#                 "gspeed": 0,
#                 "vspeed": 0,
#                 "track": 295,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:45:32Z",
#                 "lat": 63.18971,
#                 "lon": 14.52334,
#                 "alt": 0,
#                 "gspeed": 8,
#                 "vspeed": 0,
#                 "track": 295,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:45:34Z",
#                 "lat": 63.18975,
#                 "lon": 14.52314,
#                 "alt": 0,
#                 "gspeed": 14,
#                 "vspeed": 0,
#                 "track": 295,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:45:36Z",
#                 "lat": 63.18982,
#                 "lon": 14.52279,
#                 "alt": 0,
#                 "gspeed": 23,
#                 "vspeed": 0,
#                 "track": 295,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:45:43Z",
#                 "lat": 63.19052,
#                 "lon": 14.51942,
#                 "alt": 0,
#                 "gspeed": 72,
#                 "vspeed": 0,
#                 "track": 295,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:45:52Z",
#                 "lat": 63.19224,
#                 "lon": 14.51114,
#                 "alt": 1125,
#                 "gspeed": 123,
#                 "vspeed": 384,
#                 "track": 294,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:46:02Z",
#                 "lat": 63.19448,
#                 "lon": 14.49963,
#                 "alt": 1525,
#                 "gspeed": 131,
#                 "vspeed": 3776,
#                 "track": 290,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:46:04Z",
#                 "lat": 63.19503,
#                 "lon": 14.49635,
#                 "alt": 1700,
#                 "gspeed": 131,
#                 "vspeed": 3968,
#                 "track": 290,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:46:08Z",
#                 "lat": 63.19573,
#                 "lon": 14.49234,
#                 "alt": 1925,
#                 "gspeed": 130,
#                 "vspeed": 4224,
#                 "track": 290,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:46:11Z",
#                 "lat": 63.19634,
#                 "lon": 14.48854,
#                 "alt": 2150,
#                 "gspeed": 129,
#                 "vspeed": 4352,
#                 "track": 290,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:46:14Z",
#                 "lat": 63.19699,
#                 "lon": 14.48463,
#                 "alt": 2400,
#                 "gspeed": 129,
#                 "vspeed": 4288,
#                 "track": 290,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:46:17Z",
#                 "lat": 63.1976,
#                 "lon": 14.48114,
#                 "alt": 2600,
#                 "gspeed": 129,
#                 "vspeed": 4224,
#                 "track": 290,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:46:23Z",
#                 "lat": 63.19899,
#                 "lon": 14.47306,
#                 "alt": 3075,
#                 "gspeed": 132,
#                 "vspeed": 4160,
#                 "track": 291,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:46:32Z",
#                 "lat": 63.20114,
#                 "lon": 14.46136,
#                 "alt": 3700,
#                 "gspeed": 141,
#                 "vspeed": 4288,
#                 "track": 293,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:46:38Z",
#                 "lat": 63.20281,
#                 "lon": 14.45325,
#                 "alt": 4150,
#                 "gspeed": 144,
#                 "vspeed": 4544,
#                 "track": 295,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:46:41Z",
#                 "lat": 63.2037,
#                 "lon": 14.44946,
#                 "alt": 4375,
#                 "gspeed": 146,
#                 "vspeed": 4480,
#                 "track": 297,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:46:44Z",
#                 "lat": 63.20476,
#                 "lon": 14.44512,
#                 "alt": 4600,
#                 "gspeed": 149,
#                 "vspeed": 4224,
#                 "track": 298,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:46:47Z",
#                 "lat": 63.20581,
#                 "lon": 14.44079,
#                 "alt": 4825,
#                 "gspeed": 154,
#                 "vspeed": 3840,
#                 "track": 299,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:46:50Z",
#                 "lat": 63.20691,
#                 "lon": 14.43647,
#                 "alt": 5000,
#                 "gspeed": 159,
#                 "vspeed": 3648,
#                 "track": 299,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:05Z",
#                 "lat": 63.21245,
#                 "lon": 14.41332,
#                 "alt": 5950,
#                 "gspeed": 180,
#                 "vspeed": 4224,
#                 "track": 296,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:18Z",
#                 "lat": 63.21661,
#                 "lon": 14.39177,
#                 "alt": 6925,
#                 "gspeed": 192,
#                 "vspeed": 4736,
#                 "track": 285,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:21Z",
#                 "lat": 63.21716,
#                 "lon": 14.38586,
#                 "alt": 7175,
#                 "gspeed": 195,
#                 "vspeed": 4928,
#                 "track": 279,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:24Z",
#                 "lat": 63.21744,
#                 "lon": 14.37941,
#                 "alt": 7425,
#                 "gspeed": 199,
#                 "vspeed": 5056,
#                 "track": 274,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:27Z",
#                 "lat": 63.21743,
#                 "lon": 14.37341,
#                 "alt": 7675,
#                 "gspeed": 204,
#                 "vspeed": 5248,
#                 "track": 268,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:30Z",
#                 "lat": 63.21719,
#                 "lon": 14.36759,
#                 "alt": 7925,
#                 "gspeed": 207,
#                 "vspeed": 4992,
#                 "track": 262,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:33Z",
#                 "lat": 63.21668,
#                 "lon": 14.36034,
#                 "alt": 8175,
#                 "gspeed": 211,
#                 "vspeed": 4672,
#                 "track": 259,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:36Z",
#                 "lat": 63.21598,
#                 "lon": 14.35441,
#                 "alt": 8400,
#                 "gspeed": 217,
#                 "vspeed": 4480,
#                 "track": 254,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:39Z",
#                 "lat": 63.21482,
#                 "lon": 14.34716,
#                 "alt": 8650,
#                 "gspeed": 223,
#                 "vspeed": 4480,
#                 "track": 247,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:42Z",
#                 "lat": 63.21346,
#                 "lon": 14.34107,
#                 "alt": 8875,
#                 "gspeed": 230,
#                 "vspeed": 4544,
#                 "track": 240,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:45Z",
#                 "lat": 63.21176,
#                 "lon": 14.33547,
#                 "alt": 9075,
#                 "gspeed": 235,
#                 "vspeed": 4544,
#                 "track": 234,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:48Z",
#                 "lat": 63.20947,
#                 "lon": 14.32955,
#                 "alt": 9325,
#                 "gspeed": 242,
#                 "vspeed": 4672,
#                 "track": 227,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:52Z",
#                 "lat": 63.20677,
#                 "lon": 14.32386,
#                 "alt": 9600,
#                 "gspeed": 246,
#                 "vspeed": 4864,
#                 "track": 220,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:55Z",
#                 "lat": 63.20393,
#                 "lon": 14.31941,
#                 "alt": 9850,
#                 "gspeed": 250,
#                 "vspeed": 4992,
#                 "track": 213,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:47:57Z",
#                 "lat": 63.201,
#                 "lon": 14.31569,
#                 "alt": 10075,
#                 "gspeed": 254,
#                 "vspeed": 4928,
#                 "track": 207,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:00Z",
#                 "lat": 63.19798,
#                 "lon": 14.31274,
#                 "alt": 10300,
#                 "gspeed": 258,
#                 "vspeed": 4800,
#                 "track": 202,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:04Z",
#                 "lat": 63.19409,
#                 "lon": 14.31,
#                 "alt": 10575,
#                 "gspeed": 262,
#                 "vspeed": 4672,
#                 "track": 195,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:07Z",
#                 "lat": 63.19048,
#                 "lon": 14.30847,
#                 "alt": 10800,
#                 "gspeed": 266,
#                 "vspeed": 4480,
#                 "track": 188,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:09Z",
#                 "lat": 63.18689,
#                 "lon": 14.3079,
#                 "alt": 11025,
#                 "gspeed": 270,
#                 "vspeed": 4352,
#                 "track": 181,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:13Z",
#                 "lat": 63.18288,
#                 "lon": 14.30821,
#                 "alt": 11250,
#                 "gspeed": 274,
#                 "vspeed": 4224,
#                 "track": 174,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:16Z",
#                 "lat": 63.17871,
#                 "lon": 14.30979,
#                 "alt": 11475,
#                 "gspeed": 277,
#                 "vspeed": 4032,
#                 "track": 167,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:19Z",
#                 "lat": 63.175,
#                 "lon": 14.31224,
#                 "alt": 11675,
#                 "gspeed": 280,
#                 "vspeed": 3840,
#                 "track": 161,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:22Z",
#                 "lat": 63.17171,
#                 "lon": 14.31508,
#                 "alt": 11825,
#                 "gspeed": 284,
#                 "vspeed": 3648,
#                 "track": 157,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:25Z",
#                 "lat": 63.16771,
#                 "lon": 14.31941,
#                 "alt": 12025,
#                 "gspeed": 289,
#                 "vspeed": 3456,
#                 "track": 151,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:28Z",
#                 "lat": 63.1645,
#                 "lon": 14.32374,
#                 "alt": 12175,
#                 "gspeed": 291,
#                 "vspeed": 3328,
#                 "track": 147,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:31Z",
#                 "lat": 63.16086,
#                 "lon": 14.32953,
#                 "alt": 12375,
#                 "gspeed": 294,
#                 "vspeed": 3328,
#                 "track": 142,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:34Z",
#                 "lat": 63.15816,
#                 "lon": 14.33451,
#                 "alt": 12500,
#                 "gspeed": 296,
#                 "vspeed": 3584,
#                 "track": 138,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:37Z",
#                 "lat": 63.15486,
#                 "lon": 14.34102,
#                 "alt": 12700,
#                 "gspeed": 300,
#                 "vspeed": 3584,
#                 "track": 138,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:40Z",
#                 "lat": 63.15118,
#                 "lon": 14.34814,
#                 "alt": 12900,
#                 "gspeed": 302,
#                 "vspeed": 3648,
#                 "track": 139,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:43Z",
#                 "lat": 63.14827,
#                 "lon": 14.35343,
#                 "alt": 13075,
#                 "gspeed": 305,
#                 "vspeed": 3584,
#                 "track": 140,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:46Z",
#                 "lat": 63.14504,
#                 "lon": 14.35903,
#                 "alt": 13225,
#                 "gspeed": 308,
#                 "vspeed": 3456,
#                 "track": 142,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:50Z",
#                 "lat": 63.14113,
#                 "lon": 14.36557,
#                 "alt": 13425,
#                 "gspeed": 312,
#                 "vspeed": 3328,
#                 "track": 142,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:48:52Z",
#                 "lat": 63.13779,
#                 "lon": 14.37113,
#                 "alt": 13575,
#                 "gspeed": 315,
#                 "vspeed": 3264,
#                 "track": 143,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:49:23Z",
#                 "lat": 63.09923,
#                 "lon": 14.43297,
#                 "alt": 15125,
#                 "gspeed": 348,
#                 "vspeed": 3392,
#                 "track": 144,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:49:57Z",
#                 "lat": 63.0558,
#                 "lon": 14.50132,
#                 "alt": 17150,
#                 "gspeed": 349,
#                 "vspeed": 3776,
#                 "track": 144,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:50:28Z",
#                 "lat": 63.01423,
#                 "lon": 14.56629,
#                 "alt": 18825,
#                 "gspeed": 362,
#                 "vspeed": 2816,
#                 "track": 144,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:50:58Z",
#                 "lat": 62.97089,
#                 "lon": 14.63379,
#                 "alt": 20275,
#                 "gspeed": 380,
#                 "vspeed": 3008,
#                 "track": 144,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:51:29Z",
#                 "lat": 62.92593,
#                 "lon": 14.70337,
#                 "alt": 21900,
#                 "gspeed": 387,
#                 "vspeed": 3008,
#                 "track": 144,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:52:02Z",
#                 "lat": 62.8782,
#                 "lon": 14.77714,
#                 "alt": 23475,
#                 "gspeed": 395,
#                 "vspeed": 3008,
#                 "track": 144,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:52:35Z",
#                 "lat": 62.82816,
#                 "lon": 14.85413,
#                 "alt": 25000,
#                 "gspeed": 407,
#                 "vspeed": 2624,
#                 "track": 144,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:53:09Z",
#                 "lat": 62.77523,
#                 "lon": 14.93517,
#                 "alt": 26450,
#                 "gspeed": 423,
#                 "vspeed": 2752,
#                 "track": 144,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:53:39Z",
#                 "lat": 62.72607,
#                 "lon": 15.01007,
#                 "alt": 27900,
#                 "gspeed": 425,
#                 "vspeed": 2816,
#                 "track": 145,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:54:13Z",
#                 "lat": 62.67123,
#                 "lon": 15.09363,
#                 "alt": 29100,
#                 "gspeed": 440,
#                 "vspeed": 2112,
#                 "track": 145,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:54:44Z",
#                 "lat": 62.618,
#                 "lon": 15.17415,
#                 "alt": 30225,
#                 "gspeed": 451,
#                 "vspeed": 2304,
#                 "track": 145,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:55:16Z",
#                 "lat": 62.56302,
#                 "lon": 15.25696,
#                 "alt": 31325,
#                 "gspeed": 457,
#                 "vspeed": 1856,
#                 "track": 145,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:55:48Z",
#                 "lat": 62.50786,
#                 "lon": 15.33956,
#                 "alt": 32250,
#                 "gspeed": 469,
#                 "vspeed": 1856,
#                 "track": 145,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:56:20Z",
#                 "lat": 62.45034,
#                 "lon": 15.42523,
#                 "alt": 33200,
#                 "gspeed": 480,
#                 "vspeed": 1600,
#                 "track": 145,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:56:51Z",
#                 "lat": 62.39291,
#                 "lon": 15.51036,
#                 "alt": 34075,
#                 "gspeed": 484,
#                 "vspeed": 1536,
#                 "track": 145,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:57:24Z",
#                 "lat": 62.33203,
#                 "lon": 15.59987,
#                 "alt": 35000,
#                 "gspeed": 490,
#                 "vspeed": 1792,
#                 "track": 145,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:57:54Z",
#                 "lat": 62.27486,
#                 "lon": 15.6838,
#                 "alt": 35950,
#                 "gspeed": 491,
#                 "vspeed": 1856,
#                 "track": 145,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:58:25Z",
#                 "lat": 62.21697,
#                 "lon": 15.76813,
#                 "alt": 36775,
#                 "gspeed": 491,
#                 "vspeed": 1600,
#                 "track": 146,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:58:56Z",
#                 "lat": 62.15666,
#                 "lon": 15.83781,
#                 "alt": 37625,
#                 "gspeed": 483,
#                 "vspeed": 1856,
#                 "track": 157,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:58:58Z",
#                 "lat": 62.15085,
#                 "lon": 15.84269,
#                 "alt": 37725,
#                 "gspeed": 482,
#                 "vspeed": 1856,
#                 "track": 158,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:59:02Z",
#                 "lat": 62.14462,
#                 "lon": 15.84768,
#                 "alt": 37825,
#                 "gspeed": 481,
#                 "vspeed": 1920,
#                 "track": 159,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:59:04Z",
#                 "lat": 62.13858,
#                 "lon": 15.85232,
#                 "alt": 37900,
#                 "gspeed": 480,
#                 "vspeed": 1920,
#                 "track": 160,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:59:08Z",
#                 "lat": 62.1315,
#                 "lon": 15.85744,
#                 "alt": 38000,
#                 "gspeed": 479,
#                 "vspeed": 1920,
#                 "track": 161,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:59:11Z",
#                 "lat": 62.12564,
#                 "lon": 15.86161,
#                 "alt": 38100,
#                 "gspeed": 477,
#                 "vspeed": 1920,
#                 "track": 161,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:59:14Z",
#                 "lat": 62.11917,
#                 "lon": 15.86602,
#                 "alt": 38200,
#                 "gspeed": 477,
#                 "vspeed": 1856,
#                 "track": 162,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:59:17Z",
#                 "lat": 62.11391,
#                 "lon": 15.86955,
#                 "alt": 38275,
#                 "gspeed": 476,
#                 "vspeed": 1856,
#                 "track": 162,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T15:59:50Z",
#                 "lat": 62.0419,
#                 "lon": 15.91222,
#                 "alt": 38950,
#                 "gspeed": 479,
#                 "vspeed": 192,
#                 "track": 165,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:00:23Z",
#                 "lat": 61.97026,
#                 "lon": 15.95068,
#                 "alt": 38950,
#                 "gspeed": 485,
#                 "vspeed": 0,
#                 "track": 165,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:00:54Z",
#                 "lat": 61.90316,
#                 "lon": 15.98572,
#                 "alt": 38950,
#                 "gspeed": 495,
#                 "vspeed": 0,
#                 "track": 166,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:01:28Z",
#                 "lat": 61.82752,
#                 "lon": 16.02458,
#                 "alt": 38950,
#                 "gspeed": 515,
#                 "vspeed": 0,
#                 "track": 166,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:02:01Z",
#                 "lat": 61.75019,
#                 "lon": 16.06435,
#                 "alt": 38925,
#                 "gspeed": 522,
#                 "vspeed": 0,
#                 "track": 166,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:02:31Z",
#                 "lat": 61.67953,
#                 "lon": 16.10066,
#                 "alt": 38950,
#                 "gspeed": 517,
#                 "vspeed": 0,
# ...
#                 "track": 11,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:33:36Z",
#                 "lat": 59.64673,
#                 "lon": 17.95405,
#                 "alt": 0,
#                 "gspeed": 24,
#                 "vspeed": 0,
#                 "track": 11,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:33:38Z",
#                 "lat": 59.647,
#                 "lon": 17.95415,
#                 "alt": 0,
#                 "gspeed": 25,
#                 "vspeed": 0,
#                 "track": 11,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:33:45Z",
#                 "lat": 59.64782,
#                 "lon": 17.95445,
#                 "alt": 0,
#                 "gspeed": 26,
#                 "vspeed": 0,
#                 "track": 11,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:33:52Z",
#                 "lat": 59.64864,
#                 "lon": 17.95475,
#                 "alt": 0,
#                 "gspeed": 26,
#                 "vspeed": 0,
#                 "track": 11,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:01Z",
#                 "lat": 59.64967,
#                 "lon": 17.95507,
#                 "alt": 0,
#                 "gspeed": 25,
#                 "vspeed": 0,
#                 "track": 5,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:03Z",
#                 "lat": 59.6499,
#                 "lon": 17.95509,
#                 "alt": 0,
#                 "gspeed": 25,
#                 "vspeed": 0,
#                 "track": 2,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:05Z",
#                 "lat": 59.65014,
#                 "lon": 17.95509,
#                 "alt": 0,
#                 "gspeed": 26,
#                 "vspeed": 0,
#                 "track": 2,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:07Z",
#                 "lat": 59.65049,
#                 "lon": 17.95505,
#                 "alt": 0,
#                 "gspeed": 26,
#                 "vspeed": 0,
#                 "track": 351,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:11Z",
#                 "lat": 59.65092,
#                 "lon": 17.95488,
#                 "alt": 0,
#                 "gspeed": 26,
#                 "vspeed": 0,
#                 "track": 345,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:14Z",
#                 "lat": 59.65124,
#                 "lon": 17.9547,
#                 "alt": 0,
#                 "gspeed": 26,
#                 "vspeed": 0,
#                 "track": 345,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:16Z",
#                 "lat": 59.65149,
#                 "lon": 17.95457,
#                 "alt": 0,
#                 "gspeed": 25,
#                 "vspeed": 0,
#                 "track": 345,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:18Z",
#                 "lat": 59.65171,
#                 "lon": 17.95445,
#                 "alt": 0,
#                 "gspeed": 25,
#                 "vspeed": 0,
#                 "track": 345,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:21Z",
#                 "lat": 59.65208,
#                 "lon": 17.95427,
#                 "alt": 0,
#                 "gspeed": 24,
#                 "vspeed": 0,
#                 "track": 345,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:25Z",
#                 "lat": 59.65252,
#                 "lon": 17.95405,
#                 "alt": 0,
#                 "gspeed": 23,
#                 "vspeed": 0,
#                 "track": 345,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:28Z",
#                 "lat": 59.65282,
#                 "lon": 17.95388,
#                 "alt": 0,
#                 "gspeed": 23,
#                 "vspeed": 0,
#                 "track": 345,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:32Z",
#                 "lat": 59.65324,
#                 "lon": 17.95365,
#                 "alt": 0,
#                 "gspeed": 24,
#                 "vspeed": 0,
#                 "track": 343,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:39Z",
#                 "lat": 59.65403,
#                 "lon": 17.95325,
#                 "alt": 0,
#                 "gspeed": 25,
#                 "vspeed": 0,
#                 "track": 345,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:47Z",
#                 "lat": 59.65488,
#                 "lon": 17.95278,
#                 "alt": 0,
#                 "gspeed": 25,
#                 "vspeed": 0,
#                 "track": 345,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:34:54Z",
#                 "lat": 59.65566,
#                 "lon": 17.95237,
#                 "alt": 0,
#                 "gspeed": 24,
#                 "vspeed": 0,
#                 "track": 345,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:01Z",
#                 "lat": 59.65643,
#                 "lon": 17.95197,
#                 "alt": 0,
#                 "gspeed": 21,
#                 "vspeed": 0,
#                 "track": 345,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:09Z",
#                 "lat": 59.65709,
#                 "lon": 17.95161,
#                 "alt": 0,
#                 "gspeed": 17,
#                 "vspeed": 0,
#                 "track": 345,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:17Z",
#                 "lat": 59.65767,
#                 "lon": 17.95129,
#                 "alt": 0,
#                 "gspeed": 14,
#                 "vspeed": 0,
#                 "track": 343,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:23Z",
#                 "lat": 59.65805,
#                 "lon": 17.95114,
#                 "alt": 0,
#                 "gspeed": 13,
#                 "vspeed": 0,
#                 "track": 354,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:28Z",
#                 "lat": 59.65836,
#                 "lon": 17.95132,
#                 "alt": 0,
#                 "gspeed": 14,
#                 "vspeed": 0,
#                 "track": 30,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:32Z",
#                 "lat": 59.65852,
#                 "lon": 17.95173,
#                 "alt": 0,
#                 "gspeed": 14,
#                 "vspeed": 0,
#                 "track": 61,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:35Z",
#                 "lat": 59.65858,
#                 "lon": 17.95197,
#                 "alt": 0,
#                 "gspeed": 14,
#                 "vspeed": 0,
#                 "track": 67,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:36Z",
#                 "lat": 59.65861,
#                 "lon": 17.95221,
#                 "alt": 0,
#                 "gspeed": 15,
#                 "vspeed": 0,
#                 "track": 73,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:39Z",
#                 "lat": 59.65866,
#                 "lon": 17.95251,
#                 "alt": 0,
#                 "gspeed": 15,
#                 "vspeed": 0,
#                 "track": 75,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:41Z",
#                 "lat": 59.65869,
#                 "lon": 17.95278,
#                 "alt": 0,
#                 "gspeed": 15,
#                 "vspeed": 0,
#                 "track": 75,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:43Z",
#                 "lat": 59.65871,
#                 "lon": 17.95306,
#                 "alt": 0,
#                 "gspeed": 15,
#                 "vspeed": 0,
#                 "track": 84,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:46Z",
#                 "lat": 59.65867,
#                 "lon": 17.95348,
#                 "alt": 0,
#                 "gspeed": 15,
#                 "vspeed": 0,
#                 "track": 109,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:50Z",
#                 "lat": 59.65849,
#                 "lon": 17.95383,
#                 "alt": 0,
#                 "gspeed": 13,
#                 "vspeed": 0,
#                 "track": 146,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:55Z",
#                 "lat": 59.65822,
#                 "lon": 17.95404,
#                 "alt": 0,
#                 "gspeed": 13,
#                 "vspeed": 0,
#                 "track": 163,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:35:59Z",
#                 "lat": 59.65796,
#                 "lon": 17.95417,
#                 "alt": 0,
#                 "gspeed": 12,
#                 "vspeed": 0,
#                 "track": 165,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:36:03Z",
#                 "lat": 59.65775,
#                 "lon": 17.95427,
#                 "alt": 0,
#                 "gspeed": 12,
#                 "vspeed": 0,
#                 "track": 165,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:36:07Z",
#                 "lat": 59.65752,
#                 "lon": 17.95438,
#                 "alt": 0,
#                 "gspeed": 12,
#                 "vspeed": 0,
#                 "track": 165,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:36:14Z",
#                 "lat": 59.65714,
#                 "lon": 17.95459,
#                 "alt": 0,
#                 "gspeed": 12,
#                 "vspeed": 0,
#                 "track": 163,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:36:19Z",
#                 "lat": 59.65691,
#                 "lon": 17.95471,
#                 "alt": 0,
#                 "gspeed": 11,
#                 "vspeed": 0,
#                 "track": 163,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:36:23Z",
#                 "lat": 59.6567,
#                 "lon": 17.95486,
#                 "alt": 0,
#                 "gspeed": 10,
#                 "vspeed": 0,
#                 "track": 160,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:36:31Z",
#                 "lat": 59.65641,
#                 "lon": 17.95505,
#                 "alt": 0,
#                 "gspeed": 8,
#                 "vspeed": 0,
#                 "track": 168,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:36:39Z",
#                 "lat": 59.65617,
#                 "lon": 17.95502,
#                 "alt": 0,
#                 "gspeed": 5,
#                 "vspeed": 0,
#                 "track": 208,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:36:46Z",
#                 "lat": 59.65612,
#                 "lon": 17.95481,
#                 "alt": 0,
#                 "gspeed": 3,
#                 "vspeed": 0,
#                 "track": 255,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-11-03T16:37:07Z",
#                 "lat": 59.6563,
#                 "lon": 17.95457,
#                 "alt": 0,
#                 "gspeed": 2,
#                 "vspeed": 0,
#                 "track": 340,
#                 "squawk": "0227",
#                 "callsign": "SWE22V",
#                 "source": "ADSB"
#             }
#         ]
#     }
# ]
# GREAT SUCCESS!!!!!!!!!!

# %%
# Load the DataFrame where the index is 'flight_id'
sva_flight_tracks = pd.read_csv("../data/raw/df_flight_tracks_20240101_20241103_final_1738858556.csv", index_col="flight_id")
# Print the number of unique 'flight_id' in the DataFrame
print(f"The number of individual mission tracks is: {len(sva_flight_tracks)}")
sva_flight_tracks
# Out:
# The number of individual mission tracks is: 5452
#                                                      mission
# flight_id
# 33734149   [{'timestamp': '2024-01-01T00:26:42Z', 'lat': ...
# 33734f15   [{'timestamp': '2024-01-01T00:58:26Z', 'lat': ...
# 33735909   [{'timestamp': '2024-01-01T01:22:42Z', 'lat': ...
# 33737cab   [{'timestamp': '2024-01-01T02:58:41Z', 'lat': ...
# 33738170   [{'timestamp': '2024-01-01T03:11:58Z', 'lat': ...
# ...                                                      ...
# 37d4219d   [{'timestamp': '2024-11-03T10:45:02Z', 'lat': ...
# 37d452e7   [{'timestamp': '2024-11-03T12:09:18Z', 'lat': ...
# 37d47127   [{'timestamp': '2024-11-03T12:56:55Z', 'lat': ...
# 37d48046   [{'timestamp': '2024-11-03T13:17:45Z', 'lat': ...
# 37d4b992   [{'timestamp': '2024-11-03T14:30:48Z', 'lat': ...
#
# [5452 rows x 1 columns]

# %%
# Extract the json-format list of dictionaries from flight_id '2e638c5c' (flight_id is the index) 
mission_data = sva_flight_tracks.loc['33734f15']['mission']
print(mission_data)
# Out:
# [{'timestamp': '2024-01-01T00:58:26Z', 'lat': 63.7957, 'lon': 20.28351, 'alt': 0, 'gspeed': 1, 'vspeed': 0, 'track': 222, 'squawk': '0', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:01:09Z', 'lat': 63.79534, 'lon': 20.28299, 'alt': 0, 'gspeed': 3, 'vspeed': 0, 'track': 165, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:01:31Z', 'lat': 63.79507, 'lon': 20.28356, 'alt': 0, 'gspeed': 4, 'vspeed': 0, 'track': 135, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:01:51Z', 'lat': 63.7948, 'lon': 20.28411, 'alt': 0, 'gspeed': 4, 'vspeed': 0, 'track': 137, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:01:58Z', 'lat': 63.79469, 'lon': 20.28433, 'alt': 0, 'gspeed': 5, 'vspeed': 0, 'track': 140, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:02:05Z', 'lat': 63.79458, 'lon': 20.28455, 'alt': 0, 'gspeed': 5, 'vspeed': 0, 'track': 137, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:02:11Z', 'lat': 63.79449, 'lon': 20.2848, 'alt': 0, 'gspeed': 5, 'vspeed': 0, 'track': 126, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:02:16Z', 'lat': 63.79448, 'lon': 20.28505, 'alt': 0, 'gspeed': 5, 'vspeed': 0, 'track': 92, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:02:20Z', 'lat': 63.79449, 'lon': 20.28527, 'alt': 0, 'gspeed': 4, 'vspeed': 0, 'track': 75, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:02:27Z', 'lat': 63.79448, 'lon': 20.28551, 'alt': 0, 'gspeed': 4, 'vspeed': 0, 'track': 109, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:08:06Z', 'lat': 63.79366, 'lon': 20.28598, 'alt': 0, 'gspeed': 10, 'vspeed': 0, 'track': 163, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:08:12Z', 'lat': 63.7934, 'lon': 20.28623, 'alt': 0, 'gspeed': 11, 'vspeed': 0, 'track': 154, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:08:32Z', 'lat': 63.79245, 'lon': 20.28726, 'alt': 0, 'gspeed': 8, 'vspeed': 0, 'track': 160, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:08:37Z', 'lat': 63.79224, 'lon': 20.28722, 'alt': 0, 'gspeed': 8, 'vspeed': 0, 'track': 199, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:08:41Z', 'lat': 63.79213, 'lon': 20.287, 'alt': 0, 'gspeed': 9, 'vspeed': 0, 'track': 227, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:08:59Z', 'lat': 63.79205, 'lon': 20.28525, 'alt': 0, 'gspeed': 9, 'vspeed': 0, 'track': 250, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:09:02Z', 'lat': 63.79198, 'lon': 20.28502, 'alt': 0, 'gspeed': 10, 'vspeed': 0, 'track': 239, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:09:06Z', 'lat': 63.79187, 'lon': 20.28467, 'alt': 0, 'gspeed': 11, 'vspeed': 0, 'track': 233, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:09:09Z', 'lat': 63.79179, 'lon': 20.28446, 'alt': 0, 'gspeed': 11, 'vspeed': 0, 'track': 230, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:09:12Z', 'lat': 63.79168, 'lon': 20.28417, 'alt': 0, 'gspeed': 11, 'vspeed': 0, 'track': 225, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:09:30Z', 'lat': 63.79088, 'lon': 20.28464, 'alt': 0, 'gspeed': 15, 'vspeed': 0, 'track': 137, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024-01-01T01:09:33Z', 'lat': 63.79078, 'lon': 20.28485, 'alt': 0, 'gspeed': 18, 'vspeed': 0, 'track': 137, 'squawk': '6003', 'callsign': 'SWE04W', 'source': 'ADSB'}, {'timestamp': '2024- ...

# %%
# Convert the string to a list of dictionaries
mission_data_list = json.loads(mission_data.replace("'", '"'))

# Convert the list of dictionaries to a DataFrame
mission_data_df = pd.DataFrame(mission_data_list)
mission_data_df
# Out:
#                 timestamp       lat       lon  alt  gspeed  vspeed  track  \
# 0    2024-01-01T00:58:26Z  63.79570  20.28351    0       1       0    222
# 1    2024-01-01T01:01:09Z  63.79534  20.28299    0       3       0    165
# 2    2024-01-01T01:01:31Z  63.79507  20.28356    0       4       0    135
# 3    2024-01-01T01:01:51Z  63.79480  20.28411    0       4       0    137
# 4    2024-01-01T01:01:58Z  63.79469  20.28433    0       5       0    140
# ..                    ...       ...       ...  ...     ...     ...    ...
# 272  2024-01-01T01:52:37Z  63.79205  20.28662    0       9       0     87
# 273  2024-01-01T01:52:40Z  63.79209  20.28691    0       9       0     67
# 274  2024-01-01T01:53:02Z  63.79288  20.28691    0       9       0    343
# 275  2024-01-01T01:53:08Z  63.79312  20.28678    0      10       0    348
# 276  2024-01-01T01:53:37Z  63.79413  20.28583    0       3       0    323
#
#     squawk callsign source
# 0        0   SWE04W   ADSB
# 1     6003   SWE04W   ADSB
# 2     6003   SWE04W   ADSB
# 3     6003   SWE04W   ADSB
# 4     6003   SWE04W   ADSB
# ..     ...      ...    ...
# 272   6003   SWE04W   ADSB
# 273   6003   SWE04W   ADSB
# 274   6003   SWE04W   ADSB
# 275   6003   SWE04W   ADSB
# 276   6003   SWE04W   ADSB
#
# [277 rows x 10 columns]
